# %%
import json

# %%
import os
import sys
from pathlib import Path

CWD = Path(os.getcwd())
sys.path.append(str(CWD.parent))
from model.trie import Trie

# %%
WORDLE_TRIE_LOG = '../data/word_list_trie.json'

# %%
WORD_TRIE = Trie()
with open(WORDLE_TRIE_LOG) as f:
    WORD_TRIE.root = json.load(f)

# %%
words = WORD_TRIE.find_words('weary', '00000')
print(words)
# Out:
# {'chill', 'pisco', 'ships', 'pitch', 'pilus', 'polts', 'fuzil', 'pluff', 'unios', 'fills', 'plook', 'spook', 'comix', 'tofts', 'lobus', 'sough', 'clomp', 'pipit', 'mould', 'zombi', 'houts', 'obbos', 'guggl', 'tilts', 'zizit', 'sluts', 'hoick', 'onion', 'lipid', 'flong', 'thugs', 'tonks', 'dumbo', 'bisom', 'hoiks', 'inion', 'stops', 'tonus', 'zitis', 'pisos', 'vicus', 'ootid', 'iodid', 'toits', 'mooli', 'blush', 'mouch', 'binit', 'slums', 'modin', 'mutis', 'toffs', 'snush', 'glums', 'ungum', 'fitts', 'qophs', 'migod', 'gloom', 'botts', 'quibs', 'guids', 'ponks', 'zimbi', 'molts', 'jigot', 'stumm', 'nihil', 'unfix', 'funds', 'shims', 'filon', 'unlid', 'milos', 'flubs', 'tomos', 'sluff', 'shuns', 'flips', 'digit', 'scuft', 'tipup', 'hoons', 'pluot', 'jugum', 'schul', 'fouls', 'buchu', 'voips', 'hoing', 'bolos', 'botos', 'gouks', 'hills', 'pilot', 'dufus', 'binks', 'dibbs', 'dicts', 'sculs', 'golds', 'skits', 'gonks', 'nould', 'glout', 'dodos', 'linin', 'kondo', 'hutch', 'hotch', 'zooms', 'hilum', 'shtik', 'sluit', 'hobos', 'stool', 'glift', 'bolds', 'cubit', 'vlogs', 'sinsi', 'undid', 'poofs', 'tings', 'jumps', 'thill', 'shiso', 'pitso', 'milds', 'gibli', 'noshi', 'moloi', 'monks', 'bosom', 'stonn', 'ficin', 'quonk', 'thots', 'mosso', 'finch', 'goths', 'jibbs', 'tufts', 'himbo', 'bolts', 'snips', 'pulls', 'unpot', 'looms', 'coins', 'stoun', 'vughs', 'hitch', 'nitto', 'plish', 'snods', 'cumin', 'fulth', 'slobs', 'cupid', 'pouks', 'duomi', 'hokku', 'stoop', 'culls', 'buiks', 'molto', 'shift', 'imino', 'skill', 'fonts', 'noggs', 'hongs', 'octli', 'bodhi', 'shots', 'pouis', 'tocks', 'scuff', 'coost', 'motus', 'month', 'hokum', 'indol', 'likin', 'kilig', 'husos', 'choli', 'pomos', 'budis', 'dsomo', 'micos', 'stout', 'bonum', 'hilts', 'fugus', 'fondu', 'puton', 'stucs', 'dooks', 'posho', 'giust', 'novum', 'budos', 'piums